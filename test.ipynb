# %%
from testings import *

# %%
K = 2
L = 50
channel = 3
signal_names = ['TOX','TAX','TAY','RAV','RAZ','RRY','LAV','LAZ','LRY']   # select only three signals
signals = [signal_names[channel]]
n_steps = 30

# %%
subjects = list(range(1, 11))  # 10 subjects
X = build_X(subjects, signals, trial=1)

# %%
D = 3
W = 10

function = TransformationFunction(L,D,W)
phi_init = np.random.randn(K, L)
phi_init = phi_init / np.linalg.norm(phi_init, axis=1, keepdims=True)

# %%
X = X[:,:,0]

# %%
test_percdl_federated(X,function,phi_init=phi_init,K=K,L=L,n_steps=n_steps)
# Out:
# WARNING:2025-12-14 17:54:11,554:jax._src.xla_bridge:794: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.
# Starting PerCDL federated test...
# Initialized PerCDL federated model
# Initial estimates:
# sigma squared = 0.0001
# 	Step: 1/30
# 		CSC step: 0.20s
# 		CDU step: 0.63s
# 		loss: 5624.93
# 	Step: 2/30
# 		CSC step: 0.07s
# 		CDU step: 0.25s
# 		loss: 4360.52
# 	Step: 3/30
# 		CSC step: 0.18s
# 		CDU step: 0.48s
# 		loss: 3295.20
# 	Step: 4/30
# 		CSC step: 0.17s
# 		CDU step: 0.47s
# 		loss: 3011.86
# 	Step: 5/30
# 		CSC step: 0.09s
# 		CDU step: 0.48s
# 		loss: 2832.31
# 	Step: 6/30
# 		CSC step: 0.09s
# 		CDU step: 0.01s
# 		loss: 2807.77
# 	Step: 7/30
# 		CSC step: 0.10s
# 		CDU step: 0.02s
# 		loss: 2807.50
# 	Step: 8/30
# 		CSC step: 0.14s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 9/30
# 		CSC step: 0.13s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 10/30
# 		CSC step: 0.14s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 11/30
# 		CSC step: 0.17s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 12/30
# 		CSC step: 0.13s
# 		CDU step: 0.01s
# 		loss: 2807.37
# 	Step: 13/30
# 		CSC step: 0.24s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 14/30
# 		CSC step: 0.10s
# 		CDU step: 0.01s
# 		loss: 2807.37
# 	Step: 15/30
# 		CSC step: 0.16s
# 		CDU step: 0.01s
# 		loss: 2807.37
# 	Step: 16/30
# 		CSC step: 0.14s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 17/30
# 		CSC step: 0.18s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 18/30
# 		CSC step: 0.20s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 19/30
# 		CSC step: 0.13s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 20/30
# 		CSC step: 0.24s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 21/30
# 		CSC step: 0.21s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 22/30
# 		CSC step: 0.26s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 23/30
# 		CSC step: 0.23s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 24/30
# 		CSC step: 0.22s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 25/30
# 		CSC step: 0.17s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 26/30
# 		CSC step: 0.23s
# 		CDU step: 0.04s
# 		loss: 2807.37
# 	Step: 27/30
# 		CSC step: 0.35s
# 		CDU step: 0.04s
# 		loss: 2807.37
# 	Step: 28/30
# 		CSC step: 0.24s
# 		CDU step: 0.03s
# 		loss: 2807.37
# 	Step: 29/30
# 		CSC step: 0.19s
# 		CDU step: 0.02s
# 		loss: 2807.37
# 	Step: 30/30
# 		CSC step: 0.24s
# 		CDU step: 0.01s
# 		loss: 2807.37
# Personalization:
# 	Step: 1/30
# 		CSC step: 0.43s
# 2117.5017 2810.3123
# 		IPU step: 2.60s
# sigma squared = 0.0001
# 		CDU-IPU step: 2.16s
# sigma squared = 0.0001
# sigma squared = 0.0001
# sigma squared = 0.0001
# 		Barycenter step: 1.17s
# 		CSC step: 0.21s
# 		loss: 2549.88
# 	Step: 2/30
# 		CSC step: 0.16s
# 		CDU-IPU step: 1.80s
# 		Barycenter step: 0.00s
# 		CSC step: 0.26s
# 		loss: 2537.23
# 	Step: 3/30
# 		CSC step: 0.26s
# 		CDU-IPU step: 1.58s
# 		Barycenter step: 0.00s
# 		CSC step: 0.20s
# 		loss: 2526.42
# 	Step: 4/30
# 		CSC step: 2.67s
# 		CDU-IPU step: 1.74s
# 		Barycenter step: 0.00s
# 		CSC step: 0.23s
# 		loss: 2531.87
# 	Step: 5/30
# 		CSC step: 0.14s
# 		CDU-IPU step: 1.72s
# 		Barycenter step: 0.00s
# 		CSC step: 0.39s
# 		loss: 2486.45
# 	Step: 6/30
# 		CSC step: 0.20s
# 		CDU-IPU step: 1.71s
# 		Barycenter step: 0.00s
# 		CSC step: 0.19s
# 		loss: 2450.37
# 	Step: 7/30
# 		CSC step: 0.13s
# 		CDU-IPU step: 1.62s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2492.13
# 	Step: 8/30
# 		CSC step: 0.20s
# 		CDU-IPU step: 1.65s
# 		Barycenter step: 0.00s
# 		CSC step: 0.17s
# 		loss: 2469.33
# 	Step: 9/30
# 		CSC step: 0.13s
# 		CDU-IPU step: 1.77s
# 		Barycenter step: 0.00s
# 		CSC step: 0.22s
# 		loss: 2447.81
# 	Step: 10/30
# 		CSC step: 0.20s
# 		CDU-IPU step: 1.73s
# 		Barycenter step: 0.00s
# 		CSC step: 0.26s
# 		loss: 2444.39
# 	Step: 11/30
# 		CSC step: 0.17s
# 		CDU-IPU step: 1.59s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2433.83
# 	Step: 12/30
# 		CSC step: 0.18s
# 		CDU-IPU step: 1.61s
# 		Barycenter step: 0.00s
# 		CSC step: 0.19s
# 		loss: 2435.34
# 	Step: 13/30
# 		CSC step: 0.16s
# 		CDU-IPU step: 1.73s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2448.58
# 	Step: 14/30
# 		CSC step: 0.13s
# 		CDU-IPU step: 1.63s
# 		Barycenter step: 0.00s
# 		CSC step: 0.17s
# 		loss: 2435.20
# 	Step: 15/30
# 		CSC step: 0.13s
# 		CDU-IPU step: 1.71s
# 		Barycenter step: 0.00s
# 		CSC step: 0.16s
# 		loss: 2438.81
# 	Step: 16/30
# 		CSC step: 0.08s
# 		CDU-IPU step: 1.52s
# 		Barycenter step: 0.00s
# 		CSC step: 0.32s
# 		loss: 2513.56
# 	Step: 17/30
# 		CSC step: 0.13s
# 		CDU-IPU step: 1.65s
# 		Barycenter step: 0.00s
# 		CSC step: 0.17s
# 		loss: 2457.05
# 	Step: 18/30
# 		CSC step: 0.10s
# 		CDU-IPU step: 1.59s
# 		Barycenter step: 0.00s
# 		CSC step: 0.16s
# 		loss: 2515.42
# 	Step: 19/30
# 		CSC step: 0.11s
# 		CDU-IPU step: 1.48s
# 		Barycenter step: 0.00s
# 		CSC step: 2.51s
# 		loss: 2450.20
# 	Step: 20/30
# 		CSC step: 0.25s
# 		CDU-IPU step: 1.56s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2421.94
# 	Step: 21/30
# 		CSC step: 0.12s
# 		CDU-IPU step: 1.63s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2405.81
# 	Step: 22/30
# 		CSC step: 0.14s
# 		CDU-IPU step: 1.50s
# 		Barycenter step: 0.00s
# 		CSC step: 0.17s
# 		loss: 2408.92
# 	Step: 23/30
# 		CSC step: 0.11s
# 		CDU-IPU step: 1.56s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2436.46
# 	Step: 24/30
# 		CSC step: 0.10s
# 		CDU-IPU step: 1.50s
# 		Barycenter step: 0.00s
# 		CSC step: 0.15s
# 		loss: 2400.12
# 	Step: 25/30
# 		CSC step: 0.10s
# 		CDU-IPU step: 1.65s
# 		Barycenter step: 0.00s
# 		CSC step: 0.17s
# 		loss: 2419.54
# 	Step: 26/30
# 		CSC step: 0.09s
# 		CDU-IPU step: 1.44s
# 		Barycenter step: 0.00s
# 		CSC step: 0.15s
# 		loss: 2418.52
# 	Step: 27/30
# 		CSC step: 0.10s
# 		CDU-IPU step: 1.55s
# 		Barycenter step: 0.00s
# 		CSC step: 0.16s
# 		loss: 2408.56
# 	Step: 28/30
# 		CSC step: 0.10s
# 		CDU-IPU step: 1.46s
# 		Barycenter step: 0.00s
# 		CSC step: 0.15s
# 		loss: 2401.53
# 	Step: 29/30
# 		CSC step: 0.10s
# 		CDU-IPU step: 1.51s
# 		Barycenter step: 0.00s
# 		CSC step: 0.18s
# 		loss: 2350.67
# 	Step: 30/30
# 		CSC step: 0.09s
# 		CDU-IPU step: 1.45s
# 		Barycenter step: 0.00s
# 		CSC step: 0.19s
# 		loss: 2359.13
# Ran PerCDL federated model
#
# ============================================================
#   FULL TIME-WARPING ANALYSIS - Subject 0/10
# ============================================================
# /mnt/c/Users/ayman/OneDrive/Bureau/project/PerCDL-PyTorch/testings.py:37: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   plot_results(torch.tensor(X[..., None]), torch.tensor(model.Z), torch.tensor(model.A), torch.tensor(model.Phi[...,None]), function)
#  Global MSE (General): 3.7615e-01
#  Global MSE (Warped) : 3.5097e-01
#  Improvement Gain    : 6.69%
#
# --- Warped Reconstruction Visualization (Subject 0) ---
# --- MSE Comparison (Subject 0) ---
# --- General vs. Personalized Atoms (Subject 0) ---
# Plotted results
# PerCDL federated test completed.

# %%
test_our_model(X,signals,K=K,L=L,n_steps=n_steps,percentile=None)
# Out:
# Starting PerCDL test...
# /mnt/c/Users/ayman/OneDrive/Bureau/project/PerCDL-PyTorch/testings.py:63: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   X_filtered = torch.tensor(X_filtered, dtype=torch.float32)
# Ran PerCDL model
# Shapes - X: torch.Size([10, 800, 1]), z: torch.Size([10, 2, 751]), a: torch.Size([10, 2, 30]), phi: torch.Size([2, 50, 1])
#
# ============================================================
#   FULL TIME-WARPING ANALYSIS - Subject 0/10
# ============================================================
#
#  Global MSE (General): 3.3754e-01
#  Global MSE (Warped) : 2.6509e-01
#  Improvement Gain    : 21.47%
#
# --- Warped Reconstruction Visualization (Subject 0) ---
# --- MSE Comparison (Subject 0) ---
# --- General vs. Personalized Atoms (Subject 0) ---
# Plotted results
# PerCDL test completed.
